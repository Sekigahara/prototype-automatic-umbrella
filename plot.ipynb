# %%
import os
import json
import glob
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    average_precision_score,
    brier_score_loss,
    confusion_matrix,
)

# %%
LOG_DIR = Path("evaluation_logs")
THRESHOLD = 0.5

N_FOLDS = len(glob.glob(
    os.path.join("evaluation_logs", "*.json")
)) - 1

# %%
from modules.evaluations import evaluate_all_folds
from modules.plotting import plot_rain_distribution, plot_fold_metrics, plot_rainy_folds, pooled_metrics

results = evaluate_all_folds(
    LOG_DIR,
    n_folds=N_FOLDS,
    threshold=THRESHOLD
)
# Out:
# Fold 01 | Rain=   0 | Accuracy=1.000 | Closed=1.000 | Recall=nan | Precision=nan | F1=nan
# Fold 02 | Rain=   0 | Accuracy=1.000 | Closed=1.000 | Recall=nan | Precision=nan | F1=nan
# Fold 03 | Rain=   0 | Accuracy=1.000 | Closed=1.000 | Recall=nan | Precision=nan | F1=nan
# Fold 04 | Rain=   0 | Accuracy=1.000 | Closed=1.000 | Recall=nan | Precision=nan | F1=nan
# Fold 05 | Rain=   0 | Accuracy=1.000 | Closed=1.000 | Recall=nan | Precision=nan | F1=nan
# Fold 06 | Rain=   0 | Accuracy=1.000 | Closed=1.000 | Recall=nan | Precision=nan | F1=nan
# Fold 07 | Rain=   0 | Accuracy=1.000 | Closed=1.000 | Recall=nan | Precision=nan | F1=nan
# Fold 08 | Rain= 150 | Accuracy=0.943 | Closed=0.945 | Recall=0.927 | Precision=0.662 | F1=0.772
# Fold 09 | Rain=   0 | Accuracy=1.000 | Closed=1.000 | Recall=nan | Precision=nan | F1=nan
# Fold 10 | Rain=   0 | Accuracy=1.000 | Closed=1.000 | Recall=nan | Precision=nan | F1=nan
# ...

# %%
results
# Out:
#     fold        date  n_minutes  rain_minutes  dry_minutes  \
# 0      1  2026-01-06       1440             0         1440
# 1      2  2026-01-11       1440             0         1440
# 2      3  2026-01-16       1440             0         1440
# 3      4  2026-01-21       1440             0         1440
# 4      5  2026-01-26       1440             0         1440
# 5      6  2026-01-31       1440             0         1440
# 6      7  2026-02-05       1438             0         1438
# 7      8  2026-02-10       1440           150         1290
# 8      9  2026-02-15       1440             0         1440
# 9     10  2026-02-20       1440             0         1440
# 10    11  2026-02-25       1438            32         1406
# 11    12  2026-03-02       1440           988          452
# 12    13  2026-03-07       1440             0         1440
# 13    14  2026-03-12       1440            60         1380
# 14    15  2026-03-17       1440             0         1440
# ...

# %%
plot_fold_metrics(results)

# %%
plot_rain_distribution(results)

# %%
plot_rainy_folds(results, LOG_DIR)

# %%
pooled_metrics(results)
# Out:
# {'TP': 2998,
#  'TN': 57396,
#  'FP': 633,
#  'FN': 98,
#  'Accuracy': 0.988040899795501,
#  'Closed Accuracy': 0.9890916610660188,
#  'Rain Recall': 0.9683462532299741,
#  'Open Precision': 0.8256678600936381,
#  'F1': 0.8913334324364501}
